# %%
import pandas
import numpy
import matplotlib
import matplotlib.pyplot as plt

df = pandas.read_csv("gramms.csv")

df['gramms'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print(df.gramms.describe())
# Out:
# count    24.000000
# mean      4.524583
# std       0.177910
# min       4.150000
# 25%       4.457500
# 50%       4.485000
# 75%       4.522500
# max       5.090000
# Name: gramms, dtype: float64

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from scipy import stats

# If the K-S statistic is small or the p-value is high, then we cannot reject the hypothesis that the distributions of the two samples are the same.
print(stats.kstest(df, 'norm', (df.mean(), df.std()), N=len(df)))
# Out:
# KstestResult(statistic=0.9992587916472513, pvalue=1.5121584839445173e-75)
