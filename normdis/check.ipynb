# %%
import pandas
import numpy
import matplotlib
import matplotlib.pyplot as plt

df = pandas.read_csv("gramms.csv")

df['gramms'].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
print(df.gramms.describe())
# Out:
# count    24.000000
# mean     48.291667
# std      15.540911
# min       9.000000
# 25%      44.250000
# 50%      47.500000
# 75%      52.000000
# max      87.000000
# Name: gramms, dtype: float64

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from scipy import stats

# If the K-S statistic is small or the p-value is high, then we cannot reject the hypothesis that the distributions of the two samples are the same.
print(stats.kstest(df, 'norm', (df.mean(), df.std()), N=len(df)))
# Out:
# KstestResult(statistic=0.9942687407732304, pvalue=3.15523163886327e-54)
